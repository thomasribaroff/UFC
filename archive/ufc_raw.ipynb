# %%
import pandas as pd
ufc = pd.read_csv('data.csv')
meta = pd.read_csv('raw_total_fight_data.csv', sep=';')
ufc.info
# Out:
# <bound method DataFrame.info of                  R_fighter       B_fighter               Referee        date  \
# 0             Henry Cejudo   Marlon Moraes          Marc Goddard  2019-06-08
# 1     Valentina Shevchenko     Jessica Eye       Robert Madrigal  2019-06-08
# 2            Tony Ferguson  Donald Cerrone       Dan Miragliotta  2019-06-08
# 3            Jimmie Rivera        Petr Yan       Kevin MacDonald  2019-06-08
# 4              Tai Tuivasa   Blagoy Ivanov       Dan Miragliotta  2019-06-08
# ...                    ...             ...                   ...         ...
# 5139        Gerard Gordeau    Kevin Rosier  Joao Alberto Barreto  1993-11-12
# 5140          Ken Shamrock   Patrick Smith  Joao Alberto Barreto  1993-11-12
# 5141          Royce Gracie   Art Jimmerson  Joao Alberto Barreto  1993-11-12
# 5142          Kevin Rosier    Zane Frazier  Joao Alberto Barreto  1993-11-12
# 5143        Gerard Gordeau      Teila Tuli  Joao Alberto Barreto  1993-11-12
#
# ...

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
for i in ufc.columns:
    print(i)
# Out:
# R_fighter
# B_fighter
# Referee
# date
# location
# Winner
# title_bout
# weight_class
# no_of_rounds
# B_current_lose_streak
# B_current_win_streak
# B_draw
# B_avg_BODY_att
# B_avg_BODY_landed
# B_avg_CLINCH_att
# B_avg_CLINCH_landed
# B_avg_DISTANCE_att
# B_avg_DISTANCE_landed
# B_avg_GROUND_att
# B_avg_GROUND_landed
# B_avg_HEAD_att
# B_avg_HEAD_landed
# B_avg_KD
# B_avg_LEG_att
# B_avg_LEG_landed
# B_avg_PASS
# B_avg_REV
# B_avg_SIG_STR_att
# B_avg_SIG_STR_landed
# B_avg_SIG_STR_pct
# B_avg_SUB_ATT
# B_avg_TD_att
# B_avg_TD_landed
# B_avg_TD_pct
# B_avg_TOTAL_STR_att
# B_avg_TOTAL_STR_landed
# B_longest_win_streak
# B_losses
# B_avg_opp_BODY_att
# B_avg_opp_BODY_landed
# B_avg_opp_CLINCH_att
# B_avg_opp_CLINCH_landed
# B_avg_opp_DISTANCE_att
# B_avg_opp_DISTANCE_landed
# B_avg_opp_GROUND_att
# B_avg_opp_GROUND_landed
# B_avg_opp_HEAD_att
# B_avg_opp_HEAD_landed
# B_avg_opp_KD
# B_avg_opp_LEG_att
# B_avg_opp_LEG_landed
# B_avg_opp_PASS
# B_avg_opp_REV
# B_avg_opp_SIG_STR_att
# ...

# %%
meta.iloc[0]
# Out:
# R_fighter                         Henry Cejudo
# B_fighter                        Marlon Moraes
# R_KD                                         0
# B_KD                                         0
# R_SIG_STR.                           90 of 171
# B_SIG_STR.                           57 of 119
# R_SIG_STR_pct                              52%
# B_SIG_STR_pct                              47%
# R_TOTAL_STR.                         99 of 182
# B_TOTAL_STR.                         59 of 121
# R_TD                                    1 of 4
# B_TD                                    0 of 2
# R_TD_pct                                   25%
# B_TD_pct                                    0%
# R_SUB_ATT                                    1
# B_SUB_ATT                                    0
# R_PASS                                       1
# B_PASS                                       0
# R_REV                                        0
# B_REV                                        0
# ...

# %%
for i in meta.columns:
    print(i)
# Out:
# R_fighter
# B_fighter
# R_KD
# B_KD
# R_SIG_STR.
# B_SIG_STR.
# R_SIG_STR_pct
# B_SIG_STR_pct
# R_TOTAL_STR.
# B_TOTAL_STR.
# R_TD
# B_TD
# R_TD_pct
# B_TD_pct
# R_SUB_ATT
# B_SUB_ATT
# R_PASS
# B_PASS
# R_REV
# B_REV
# R_HEAD
# B_HEAD
# R_BODY
# B_BODY
# R_LEG
# B_LEG
# R_DISTANCE
# B_DISTANCE
# R_CLINCH
# B_CLINCH
# R_GROUND
# B_GROUND
# win_by
# last_round
# last_round_time
# Format
# Referee
# date
# location
# Fight_type
# Winner

# %%
meta.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           52%           47%    99 of 182    59 of 121  ...   1 of 1
# 1           72%           16%     37 of 40     42 of 52  ...   0 of 0
# 2           52%           36%   104 of 200    68 of 185  ...   0 of 0
# 3           38%           29%    76 of 195    58 of 192  ...  4 of 10
# 4           44%           59%    66 of 146    81 of 131  ...   6 of 6
#
#                     win_by last_round last_round_time             Format  \
# ...

# %%
meta['datetime']= pd.to_datetime(meta['date'],format='%B %d, %Y')

# %%
meta['newindex'] = ''
for i in range(len(meta)):
    meta['newindex'][i] = meta['R_fighter'][i]+meta['B_fighter'][i]+str(meta.datetime[i])[:10]
# Out:
# /Users/flatironschool/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
meta.head()
# Out:
#               R_fighter       B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0          Henry Cejudo   Marlon Moraes     0     0   90 of 171  57 of 119
# 1  Valentina Shevchenko     Jessica Eye     1     0     8 of 11    2 of 12
# 2         Tony Ferguson  Donald Cerrone     0     0  104 of 200  68 of 185
# 3         Jimmie Rivera        Petr Yan     0     2   73 of 192  56 of 189
# 4           Tai Tuivasa   Blagoy Ivanov     0     1   64 of 144  73 of 123
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... last_round  \
# 0           52%           47%    99 of 182    59 of 121  ...          3
# 1           72%           16%     37 of 40     42 of 52  ...          2
# 2           52%           36%   104 of 200    68 of 185  ...          2
# 3           38%           29%    76 of 195    58 of 192  ...          3
# 4           44%           59%    66 of 146    81 of 131  ...          3
#
#   last_round_time             Format          Referee           date  \
# ...

# %%
meta.newindex[0]
# Out:
# 'Henry CejudoMarlon Moraes2019-06-08'

# %%
meta.set_index(meta.newindex,inplace=True, drop=True)

# %%
meta.drop(columns=['newindex'])
# Out:
#                                                       R_fighter  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08                Henry Cejudo
# Valentina ShevchenkoJessica Eye2019-06-08  Valentina Shevchenko
# Tony FergusonDonald Cerrone2019-06-08             Tony Ferguson
# Jimmie RiveraPetr Yan2019-06-08                   Jimmie Rivera
# Tai TuivasaBlagoy Ivanov2019-06-08                  Tai Tuivasa
# ...                                                         ...
# Gerard GordeauKevin Rosier1993-11-12             Gerard Gordeau
# Ken ShamrockPatrick Smith1993-11-12                Ken Shamrock
# Royce GracieArt Jimmerson1993-11-12                Royce Gracie
# Kevin RosierZane Frazier1993-11-12                 Kevin Rosier
# Gerard GordeauTeila Tuli1993-11-12               Gerard Gordeau
#
#                                                 B_fighter  R_KD  B_KD  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08         Marlon Moraes     0     0
# ...

# %%
time_data = pd.concat([meta['datetime'], meta['last_round'], meta['last_round_time'], meta['Format'], meta['Fight_type']], axis=1)

# %%
time_data.head()
# Out:
#                                             datetime  last_round  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08       2019-06-08           3
# Valentina ShevchenkoJessica Eye2019-06-08 2019-06-08           2
# Tony FergusonDonald Cerrone2019-06-08     2019-06-08           2
# Jimmie RiveraPetr Yan2019-06-08           2019-06-08           3
# Tai TuivasaBlagoy Ivanov2019-06-08        2019-06-08           3
#
#                                           last_round_time             Format  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08                  4:51  5 Rnd (5-5-5-5-5)
# Valentina ShevchenkoJessica Eye2019-06-08            0:26  5 Rnd (5-5-5-5-5)
# Tony FergusonDonald Cerrone2019-06-08                5:00      3 Rnd (5-5-5)
# Jimmie RiveraPetr Yan2019-06-08                      5:00      3 Rnd (5-5-5)
# Tai TuivasaBlagoy Ivanov2019-06-08                   5:00      3 Rnd (5-5-5)
#
#                                                                  Fight_type
# newindex
# ...

# %%
len(time_data)
# Out:
# 5144

# %%
len(ufc)
# Out:
# 5144

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee        date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard  2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal  2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta  2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald  2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta  2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
type(ufc.date[0])
# Out:
# str

# %%
ufc.date=pd.to_datetime(ufc.date, format='%Y/%m/%d')

# %%
str(ufc.date[2])[:10]
# Out:
# '2019-06-08'

# %%
ufc['newindex'] = ''
for i in range(len(ufc)):
    ufc['newindex'][i] = ufc['R_fighter'][i]+ufc['B_fighter'][i]+str(ufc.date[i])[:10]
# Out:
# /Users/flatironschool/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
ufc.head()
# Out:
#               R_fighter       B_fighter          Referee       date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard 2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal 2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta 2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald 2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta 2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_Submission  \
# ...

# %%
ufc.set_index('newindex',inplace=True, drop=True)

# %%
ufc.head()
# Out:
#                                                       R_fighter  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08                Henry Cejudo
# Valentina ShevchenkoJessica Eye2019-06-08  Valentina Shevchenko
# Tony FergusonDonald Cerrone2019-06-08             Tony Ferguson
# Jimmie RiveraPetr Yan2019-06-08                   Jimmie Rivera
# Tai TuivasaBlagoy Ivanov2019-06-08                  Tai Tuivasa
#
#                                                 B_fighter          Referee  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08         Marlon Moraes     Marc Goddard
# Valentina ShevchenkoJessica Eye2019-06-08     Jessica Eye  Robert Madrigal
# Tony FergusonDonald Cerrone2019-06-08      Donald Cerrone  Dan Miragliotta
# Jimmie RiveraPetr Yan2019-06-08                  Petr Yan  Kevin MacDonald
# Tai TuivasaBlagoy Ivanov2019-06-08          Blagoy Ivanov  Dan Miragliotta
#
#                                                 date                location  \
# newindex
# ...

# %%
time_data.head()
# Out:
#                                             datetime  last_round  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08       2019-06-08           3
# Valentina ShevchenkoJessica Eye2019-06-08 2019-06-08           2
# Tony FergusonDonald Cerrone2019-06-08     2019-06-08           2
# Jimmie RiveraPetr Yan2019-06-08           2019-06-08           3
# Tai TuivasaBlagoy Ivanov2019-06-08        2019-06-08           3
#
#                                           last_round_time             Format  \
# newindex
# Henry CejudoMarlon Moraes2019-06-08                  4:51  5 Rnd (5-5-5-5-5)
# Valentina ShevchenkoJessica Eye2019-06-08            0:26  5 Rnd (5-5-5-5-5)
# Tony FergusonDonald Cerrone2019-06-08                5:00      3 Rnd (5-5-5)
# Jimmie RiveraPetr Yan2019-06-08                      5:00      3 Rnd (5-5-5)
# Tai TuivasaBlagoy Ivanov2019-06-08                   5:00      3 Rnd (5-5-5)
#
#                                                                  Fight_type
# newindex
# ...

# %%
type(time_data.index[0])
# Out:
# str

# %%
# joining our timetable based on the new, truly unique index

# %%
ufc_total = ufc.join(time_data)

# %%
ufc_total.head()
# Out:
#                                          R_fighter     B_fighter  \
# newindex
# Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# Aaron RileyJoe Brammer2010-05-29       Aaron Riley   Joe Brammer
# Aaron RileyJorge Gurgel2008-11-15      Aaron Riley  Jorge Gurgel
# Aaron RileyJustin Salas2013-07-27      Aaron Riley  Justin Salas
# Aaron RileyShane Nelson2009-08-08      Aaron Riley  Shane Nelson
#
#                                              Referee       date  \
# newindex
# Aaron PhillipsMatt Hobar2014-08-23         Kevin Nix 2014-08-23
# Aaron RileyJoe Brammer2010-05-29    Steve Mazzagatti 2010-05-29
# Aaron RileyJorge Gurgel2008-11-15     Mario Yamasaki 2008-11-15
# Aaron RileyJustin Salas2013-07-27       Randy Corley 2013-07-27
# Aaron RileyShane Nelson2009-08-08      Kevin Mulhall 2009-08-08
#
#                                                            location Winner  \
# newindex
# Aaron PhillipsMatt Hobar2014-08-23             Tulsa, Oklahoma, USA   Blue
# ...

# %%
len(ufc_total)
# Out:
# 5146

# %%
ufc_total.loc[ufc_total.date != ufc_total.datetime]
# Out:
# Empty DataFrame
# ...

# %%
ufc_total.datetime.dtype
# Out:
# dtype('<M8[ns]')

# %%
ufc_total.date.dtype
# Out:
# dtype('<M8[ns]')

# %%
ufc_total.date = pd.to_datetime(ufc_total.date, format='%Y/%m/%d')

# %%
ufc_total.drop(columns=['datetime'], inplace=True)

# %%
ufc_total.tail()
# Out:
#                                                  R_fighter         B_fighter  \
# newindex
# Zhang LipengBrendan O'Reilly2014-08-23        Zhang Lipeng  Brendan O'Reilly
# Zhang LipengChris Wade2015-01-18              Zhang Lipeng        Chris Wade
# Zhang LipengKajan Johnson2015-05-16           Zhang Lipeng     Kajan Johnson
# Zubaira TukhugovErnest Chavez2014-10-04   Zubaira Tukhugov     Ernest Chavez
# Zubaira TukhugovPhillipe Nover2015-12-10  Zubaira Tukhugov    Phillipe Nover
#
#                                                   Referee       date  \
# newindex
# Zhang LipengBrendan O'Reilly2014-08-23         John Sharp 2014-08-23
# Zhang LipengChris Wade2015-01-18          Kevin MacDonald 2015-01-18
# Zhang LipengKajan Johnson2015-05-16        Greg Kleynjans 2015-05-16
# Zubaira TukhugovErnest Chavez2014-10-04      Bobby Rehman 2014-10-04
# Zubaira TukhugovPhillipe Nover2015-12-10       Mark Smith 2015-12-10
#
# ...

# %%
ufc_total.last_round.value_counts()
# Out:
# 3    2526
# 1    1570
# 2     865
# 5     155
# 4      30
# Name: last_round, dtype: int64

# %%
ufc_total['time_so_far'] = (ufc_total.last_round  - 1)*pd.Timedelta(5, unit='m')

# %%
ufc_total.time_so_far.dtype
# Out:
# dtype('<m8[ns]')

# %%
ufc_total.R_Stance[9:10]
# Out:
# newindex
# Aaron SimpsonMark Munoz2010-11-20    Orthodox
# Name: R_Stance, dtype: object

# %%
ufc_total['time_so_far']
# Out:
# newindex
# Aaron PhillipsMatt Hobar2014-08-23         00:10:00
# Aaron RileyJoe Brammer2010-05-29           00:10:00
# Aaron RileyJorge Gurgel2008-11-15          00:10:00
# Aaron RileyJustin Salas2013-07-27          00:10:00
# Aaron RileyShane Nelson2009-08-08          00:10:00
#                                              ...
# Zhang LipengBrendan O'Reilly2014-08-23     00:10:00
# Zhang LipengChris Wade2015-01-18           00:10:00
# Zhang LipengKajan Johnson2015-05-16        00:10:00
# Zubaira TukhugovErnest Chavez2014-10-04    00:00:00
# Zubaira TukhugovPhillipe Nover2015-12-10   00:10:00
# Name: time_so_far, Length: 5146, dtype: timedelta64[ns]

# %%
ufc_total.reset_index(inplace=True)

# %%
(ufc_total.time_so_far[0])
# Out:
# Timedelta('0 days 00:10:00')

# %%
ufc_total['round_time_delta'] = 0
ufc_total.round_time_delta = pd.to_timedelta(ufc_total.round_time_delta, unit='s')

# %%
ufc_total.tail()
# Out:
#                                       newindex         R_fighter  \
# 5141    Zhang LipengBrendan O'Reilly2014-08-23      Zhang Lipeng
# 5142          Zhang LipengChris Wade2015-01-18      Zhang Lipeng
# 5143       Zhang LipengKajan Johnson2015-05-16      Zhang Lipeng
# 5144   Zubaira TukhugovErnest Chavez2014-10-04  Zubaira Tukhugov
# 5145  Zubaira TukhugovPhillipe Nover2015-12-10  Zubaira Tukhugov
#
#              B_fighter          Referee       date  \
# 5141  Brendan O'Reilly       John Sharp 2014-08-23
# 5142        Chris Wade  Kevin MacDonald 2015-01-18
# 5143     Kajan Johnson   Greg Kleynjans 2015-05-16
# 5144     Ernest Chavez     Bobby Rehman 2014-10-04
# 5145    Phillipe Nover       Mark Smith 2015-12-10
#
#                         location Winner  title_bout   weight_class  \
# 5141                Macau, China    Red       False    Lightweight
# 5142  Boston, Massachusetts, USA   Blue       False    Lightweight
# ...

# %%
ufc_total.last_round_time[0][2:4]
# Out:
# '00'

# %%
ufc_total.last_round_time.value_counts()[-20:]
# Out:
# 7:25     1
# 9:51     1
# 7:57     1
# 11:19    1
# 15:49    1
# 8:02     1
# 8:16     1
# 9:08     1
# 10:01    1
# 15:00    1
# 10:21    1
# 5:31     1
# 5:57     1
# 5:48     1
# 6:28     1
# 10:05    1
# 12:13    1
# 12:27    1
# 13:17    1
# 11:01    1
# Name: last_round_time, dtype: int64

# %%
(ufc_total.last_round_time.dtype)
# Out:
# dtype('O')

# %%
for i in range(len(ufc_total)):
    if len(ufc_total.last_round_time[i])==4:
        ufc_total['round_time_delta'][i] = (int(ufc_total.last_round_time[i][0])*pd.Timedelta(1, unit='m') + int(ufc_total.last_round_time[i][2:])*pd.Timedelta(1, unit='s'))
    elif len(ufc_total.last_round_time[i])>4:
        ufc_total['round_time_delta'][i] = (int(ufc_total.last_round_time[i][0:2])*pd.Timedelta(1, unit='m') + int(ufc_total.last_round_time[i][3:])*pd.Timedelta(1, unit='s'))
# Out:
# /Users/flatironschool/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/flatironschool/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
ufc_total.last_round_time[0:2]
# Out:
# 0    5:00
# 1    5:00
# Name: last_round_time, dtype: object

# %%
ufc_total.round_time_delta[0:1]
# Out:
# 0   00:05:00
# Name: round_time_delta, dtype: timedelta64[ns]

# %%
ufc_total.head()
# Out:
#                              newindex       R_fighter     B_fighter  \
# 0  Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# 1    Aaron RileyJoe Brammer2010-05-29     Aaron Riley   Joe Brammer
# 2   Aaron RileyJorge Gurgel2008-11-15     Aaron Riley  Jorge Gurgel
# 3   Aaron RileyJustin Salas2013-07-27     Aaron Riley  Justin Salas
# 4   Aaron RileyShane Nelson2009-08-08     Aaron Riley  Shane Nelson
#
#             Referee       date                         location Winner  \
# 0         Kevin Nix 2014-08-23             Tulsa, Oklahoma, USA   Blue
# 1  Steve Mazzagatti 2010-05-29           Las Vegas, Nevada, USA    Red
# 2    Mario Yamasaki 2008-11-15           Las Vegas, Nevada, USA    Red
# 3      Randy Corley 2013-07-27         Seattle, Washington, USA   Blue
# 4     Kevin Mulhall 2009-08-08  Philadelphia, Pennsylvania, USA    Red
#
#    title_bout  weight_class  no_of_rounds  ...  R_Reach_cms  R_Weight_lbs  \
# ...

# %%
# ufc_total.last_round_time = pd.to_datetime(ufc_total.last_round_time, format='%M:%S')

# %%
ufc_total.head()
# Out:
#                              newindex       R_fighter     B_fighter  \
# 0  Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# 1    Aaron RileyJoe Brammer2010-05-29     Aaron Riley   Joe Brammer
# 2   Aaron RileyJorge Gurgel2008-11-15     Aaron Riley  Jorge Gurgel
# 3   Aaron RileyJustin Salas2013-07-27     Aaron Riley  Justin Salas
# 4   Aaron RileyShane Nelson2009-08-08     Aaron Riley  Shane Nelson
#
#             Referee       date                         location Winner  \
# 0         Kevin Nix 2014-08-23             Tulsa, Oklahoma, USA   Blue
# 1  Steve Mazzagatti 2010-05-29           Las Vegas, Nevada, USA    Red
# 2    Mario Yamasaki 2008-11-15           Las Vegas, Nevada, USA    Red
# 3      Randy Corley 2013-07-27         Seattle, Washington, USA   Blue
# 4     Kevin Mulhall 2009-08-08  Philadelphia, Pennsylvania, USA    Red
#
#    title_bout  weight_class  no_of_rounds  ...  R_Reach_cms  R_Weight_lbs  \
# ...

# %%
ufc_total['TIME'] = ufc_total.time_so_far + ufc_total.round_time_delta

# %%
ufc_total.head()
# Out:
#                              newindex       R_fighter     B_fighter  \
# 0  Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# 1    Aaron RileyJoe Brammer2010-05-29     Aaron Riley   Joe Brammer
# 2   Aaron RileyJorge Gurgel2008-11-15     Aaron Riley  Jorge Gurgel
# 3   Aaron RileyJustin Salas2013-07-27     Aaron Riley  Justin Salas
# 4   Aaron RileyShane Nelson2009-08-08     Aaron Riley  Shane Nelson
#
#             Referee       date                         location Winner  \
# 0         Kevin Nix 2014-08-23             Tulsa, Oklahoma, USA   Blue
# 1  Steve Mazzagatti 2010-05-29           Las Vegas, Nevada, USA    Red
# 2    Mario Yamasaki 2008-11-15           Las Vegas, Nevada, USA    Red
# 3      Randy Corley 2013-07-27         Seattle, Washington, USA   Blue
# 4     Kevin Mulhall 2009-08-08  Philadelphia, Pennsylvania, USA    Red
#
#    title_bout  weight_class  no_of_rounds  ...  R_Weight_lbs  B_age  R_age  \
# ...

# %%
ufc_total.TIME.dtype
# Out:
# dtype('<m8[ns]')

# %%
import datetime as dt

# %%
ufc_total['TIMEmod'] = ufc_total.TIME.dt.seconds

# %%
ufc_total.head()
# Out:
#                              newindex       R_fighter     B_fighter  \
# 0  Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# 1    Aaron RileyJoe Brammer2010-05-29     Aaron Riley   Joe Brammer
# 2   Aaron RileyJorge Gurgel2008-11-15     Aaron Riley  Jorge Gurgel
# 3   Aaron RileyJustin Salas2013-07-27     Aaron Riley  Justin Salas
# 4   Aaron RileyShane Nelson2009-08-08     Aaron Riley  Shane Nelson
#
#             Referee       date                         location Winner  \
# 0         Kevin Nix 2014-08-23             Tulsa, Oklahoma, USA   Blue
# 1  Steve Mazzagatti 2010-05-29           Las Vegas, Nevada, USA    Red
# 2    Mario Yamasaki 2008-11-15           Las Vegas, Nevada, USA    Red
# 3      Randy Corley 2013-07-27         Seattle, Washington, USA   Blue
# 4     Kevin Mulhall 2009-08-08  Philadelphia, Pennsylvania, USA    Red
#
#    title_bout  weight_class  no_of_rounds  ...  B_age  R_age  last_round  \
# ...

# %%
ufc_total.TIMEmod.value_counts()
# Out:
# 900     2124
# 1500     137
# 600       36
# 480       18
# 300       18
#         ...
# 652        1
# 821        1
# 644        1
# 746        1
# 10         1
# Name: TIMEmod, Length: 834, dtype: int64

# %%
import seaborn as sns
import numpy as np
non_finish = (ufc_total.loc[ufc_total.TIMEmod!=900])
non_finish = non_finish.loc[non_finish.TIMEmod!=1500]
sns.distplot(np.sqrt(non_finish.TIMEmod));

# %%
len(non_finish)
# Out:
# 2885

# %%
ufc_total.weight_class.value_counts()
# Out:
# Lightweight              989
# Welterweight             969
# Middleweight             725
# Heavyweight              509
# Light Heavyweight        502
# Featherweight            442
# Bantamweight             379
# Flyweight                187
# Women's Strawweight      143
# Women's Bantamweight     111
# Open Weight               92
# Women's Flyweight         50
# Catch Weight              38
# Women's Featherweight     10
# Name: weight_class, dtype: int64

# %%
ufc_total_saved = pd.to_pickle(ufc_total, "./ufc_total_saved.pkl")

# %%
ufc_total = pd.read_pickle('ufc_total_saved.pkl')

# %%
ufc_total.head()
# Out:
#                              newindex       R_fighter     B_fighter  \
# 0  Aaron PhillipsMatt Hobar2014-08-23  Aaron Phillips    Matt Hobar
# 1    Aaron RileyJoe Brammer2010-05-29     Aaron Riley   Joe Brammer
# 2   Aaron RileyJorge Gurgel2008-11-15     Aaron Riley  Jorge Gurgel
# 3   Aaron RileyJustin Salas2013-07-27     Aaron Riley  Justin Salas
# 4   Aaron RileyShane Nelson2009-08-08     Aaron Riley  Shane Nelson
#
#             Referee       date                         location Winner  \
# 0         Kevin Nix 2014-08-23             Tulsa, Oklahoma, USA   Blue
# 1  Steve Mazzagatti 2010-05-29           Las Vegas, Nevada, USA    Red
# 2    Mario Yamasaki 2008-11-15           Las Vegas, Nevada, USA    Red
# 3      Randy Corley 2013-07-27         Seattle, Washington, USA   Blue
# 4     Kevin Mulhall 2009-08-08  Philadelphia, Pennsylvania, USA    Red
#
#    title_bout  weight_class  no_of_rounds  ...  B_age  R_age  last_round  \
# ...

# %%
ufc_total.tail(20)
# Out:
#                                            newindex              R_fighter  \
# 5126              Yves JabouinPablo Garza2011-04-30           Yves Jabouin
# 5127           Yves JabouinThomas Almeida2015-04-25           Yves Jabouin
# 5128   Zabit MagomedsharipovBrandon Davis2018-09-08  Zabit Magomedsharipov
# 5129   Zabit MagomedsharipovKyle Bochniak2018-04-07  Zabit Magomedsharipov
# 5130  Zabit MagomedsharipovSheymon Moraes2017-11-25  Zabit Magomedsharipov
# 5131            Zach MakovskyDustin Ortiz2016-12-10          Zach Makovsky
# 5132            Zach MakovskyJoshua Sampo2014-02-22          Zach Makovsky
# 5133             Zach MakovskyTim Elliott2015-02-14          Zach Makovsky
# 5134       Zak CummingsAlexander Yakovlev2016-11-19           Zak Cummings
# 5135            Zak CummingsBenny Alloway2013-08-28           Zak Cummings
# 5136         Zak CummingsDominique Steele2015-07-25           Zak Cummings
# ...

# %%
len(ufc_total)
# Out:
# 5146

# %%
len(ufc)
# Out:
# 5144
